# %%
import pandas as pd
from pathlib import Path

# %%
caminho_csv = Path("data/raw/viirs-snpp_2024_Brazil.csv")

if caminho_csv.exists():
    df_original = pd.read_csv(caminho_csv, chunksize = 100_00)
else: 
    print("Arquivo não encontrado")

# %%
primeiro_chunk = next(df_original)

primeiro_chunk.head(5)
# Out:
#        latitude  longitude  bright_ti4  scan  track    acq_date  acq_time  \
# 10000  -3.13515  -50.61473      348.72  0.55   0.68  2024-01-10      1736
# 10001  -2.86080  -49.05998      336.86  0.71   0.75  2024-01-10      1736
# 10002  -3.36459  -52.13813      342.28  0.43   0.62  2024-01-10      1736
# 10003  -3.13272  -50.61307      354.64  0.56   0.68  2024-01-10      1736
# 10004  -2.86289  -49.06169      330.77  0.71   0.75  2024-01-10      1736
#
#       satellite instrument confidence  version  bright_ti5    frp daynight  \
# 10000         N      VIIRS          n        2      282.74   5.98        D
# 10001         N      VIIRS          n        2      279.96   4.54        D
# 10002         N      VIIRS          n        2      286.20  10.08        D
# 10003         N      VIIRS          n        2      285.13  10.39        D
# 10004         N      VIIRS          n        2      279.23   3.66        D
#
#        type
# 10000     0
# 10001     0
# 10002     0
# 10003     0
# 10004     0
